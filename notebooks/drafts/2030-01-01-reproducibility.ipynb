# %% [markdown]
# # Reproducibility Now!
#
# Draft moved to a normal Astro blog post (better for long tutorials + foldable code):
#
# [`src/content/blog/2030-01-01-reproducibility.md`](../../src/content/blog/2030-01-01-reproducibility.md)
#
# Local preview (with the site dev server running): [http://localhost:4321/blog/2030-01-01-reproducibility/](http://localhost:4321/blog/2030-01-01-reproducibility/)
#
# **Foldable snippets** use the same pattern as the FDR post:
#
# ````markdown
# <details markdown="1">
# <summary>Label for the disclosure</summary>
#
# ```bash
# your commands here
# ```
#
# </details>
# ````
#
# Keep short one-liners as plain fences (`bash` / `nix` / `r`); wrap longer flakes and scary examples in `<details>`.
